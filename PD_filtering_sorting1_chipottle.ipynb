# %% [markdown]
# # Filtering and Sorting Data

# %%
import pandas as pd

# %% [markdown]
# ### Dataset in this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv)

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo = pd.read_csv(url, sep='\t')

print(chipo.shape)
chipo.head()
# Out:
# (4622, 5)
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Number of products > $10.00

# %%
# Strip symbols in-place and convert to float
chipo['item_price'] = chipo['item_price'].str.strip('$').astype(float)

# Test stripping and data type
print(chipo.iloc[0][4])
print(chipo['item_price'].dtype)
# Out:
# 2.39
# float64

# %%
chipo[chipo['item_price'] > 10].count()
# Out:
# order_id              1130
# quantity              1130
# item_name             1130
# choice_description    1123
# item_price            1130
# dtype: int64

# %% [markdown]
# ### Price of each item

# %%
items_prices = chipo[['item_name', 'item_price']]
items_prices.head()
# Out:
#                                item_name  item_price
# 0           Chips and Fresh Tomato Salsa        2.39
# 1                                   Izze        3.39
# 2                       Nantucket Nectar        3.39
# 3  Chips and Tomatillo-Green Chili Salsa        2.39
# 4                           Chicken Bowl       16.98

# %% [markdown]
# ### Sort by item´s name (alphabetically)

# %%
items_prices.sort_values(by='item_name')
# Out:
#               item_name  item_price
# 3389  6 Pack Soft Drink       12.98
# 341   6 Pack Soft Drink        6.49
# 1849  6 Pack Soft Drink        6.49
# 1860  6 Pack Soft Drink        6.49
# 2713  6 Pack Soft Drink        6.49
# 3422  6 Pack Soft Drink        6.49
# 553   6 Pack Soft Drink        6.49
# 1916  6 Pack Soft Drink        6.49
# 1922  6 Pack Soft Drink        6.49
# 1937  6 Pack Soft Drink        6.49
# 3836  6 Pack Soft Drink        6.49
# 298   6 Pack Soft Drink        6.49
# 1976  6 Pack Soft Drink        6.49
# 1167  6 Pack Soft Drink        6.49
# 3875  6 Pack Soft Drink        6.49
# 1124  6 Pack Soft Drink        6.49
# 3886  6 Pack Soft Drink        6.49
# 2108  6 Pack Soft Drink        6.49
# 3010  6 Pack Soft Drink        6.49
# 4535  6 Pack Soft Drink        6.49
# 4169  6 Pack Soft Drink        6.49
# 4174  6 Pack Soft Drink        6.49
# 4527  6 Pack Soft Drink        6.49
# 4522  6 Pack Soft Drink        6.49
# 3806  6 Pack Soft Drink        6.49
# ...

# %% [markdown]
# ### Quantity of the most expensive item ordered

# %%
chipo.sort_values(by='item_price', ascending=False).iloc[0]['quantity']

# OR

chipo.sort_values(by='item_price', ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### Number of Veggie Salad Bowls ordered

# %%
chipo[chipo['item_name'] == 'Veggie Salad Bowl'].iloc[:]['quantity'].sum()
# Out:
# 18

# %% [markdown]
# ### Number of times that people orderd more than one Canned Soda

# %%
chipo[(chipo['item_name'] == "Canned Soda") & (chipo['quantity'] > 1)].shape[0]
# Out:
# 20
